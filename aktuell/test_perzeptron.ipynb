# %%
# %matplotlib
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import functions.Perceptron as pc
import functions.showres as sr
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### <font color="#FF0000">Eingabezelle</font>

# %%
X = np.array([1.1, 1.1, 2.1, 1.1, 3.1, 1.1, 1.1, 3.1, 2.1, 3.1, 3.1, 3.1]).reshape(6,2)
y = np.array([-1, 1, 1, -1, -1, 1])
w = [0.0, 0.0, 0.0]

# %%
mp = pc.Perceptron(eta=0.5, n_iter=20)
mp.show_tf(X, y, tf_iter = 1)
# Out:
# 0 [-1.0, 1.9, -1.1]

# %%
ppn = pc.Perceptron(eta=1, n_iter=100)
ppn.fit(X, y, w)
plt.stem(range(1, len(ppn.errors_) + 1), ppn.errors_, markerfmt='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')
plt.show()

# %%
sr.plot_decision_regions(X, y, classifier=ppn, resolution=0.01)
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend(loc='upper left')
plt.show()
